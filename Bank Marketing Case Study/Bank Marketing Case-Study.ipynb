# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\Supriyo\Downloads\bank_marketing.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  age         job  marital  education default  balance housing  \
# 0           0   41    services  married    unknown      no       88     yes
# 1           1   56  technician  married  secondary      no     1938      no
# 2           2   30    services   single  secondary      no      245      no
# 3           3   34  management   single   tertiary      no     1396     yes
# 4           4   29  technician   single  secondary      no      -13     yes
#
#   loan   contact  day month  duration  campaign  pdays  previous poutcome  \
# 0   no  cellular   11   may       105         1    336         2  failure
# 1  yes  cellular   26   feb       229         1    192         4  success
# 2  yes  cellular    8   jul       187         2     -1         0  unknown
# 3   no  cellular   17   jul       630         1     -1         0  unknown
# 4   no  cellular   14   may       512         3     -1         0  unknown
#
#   deposit
# 0      no
# 1     yes
# 2      no
# 3      no
# ...

# %% [markdown]
# # Check how many nullvalues are there ?

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# age           0
# job           0
# marital       0
# education     0
# default       0
# balance       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# deposit       0
# dtype: int64

# %%
data_copy=data.copy()

# %% [markdown]
# # Drop the Unnamed column from the data set and tell the shape

# %%
x=data_copy.drop(['Unnamed: 0'],axis=1)

# %%
x
# Out:
#       age          job  marital  education default  balance housing loan  \
# 0      41     services  married    unknown      no       88     yes   no
# 1      56   technician  married  secondary      no     1938      no  yes
# 2      30     services   single  secondary      no      245      no  yes
# 3      34   management   single   tertiary      no     1396     yes   no
# 4      29   technician   single  secondary      no      -13     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 5576   48       admin.  married  secondary      no     2235     yes  yes
# 5577   40  blue-collar  married    primary      no     -388     yes   no
# 5578   27      student   single  secondary      no       91      no   no
# 5579   46  blue-collar  married  secondary      no     1568     yes   no
# 5580   39     services  married  secondary      no        0     yes   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
x.shape
# Out:
# (5581, 17)

# %% [markdown]
# # How many duplicate values are there ?

# %%
df=data_copy[data_copy.duplicated()]

# %%
df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, deposit]
# Index: []

# %% [markdown]
# # How many peoples choose to deposit

# %%
deposit_yes=data_copy.loc[data_copy['deposit'].isin(['yes'])]

# %%
len(deposit_yes)
# Out:
# 2622

# %%
deposit_yes
# Out:
#       Unnamed: 0  age          job   marital  education default  balance  \
# 1              1   56   technician   married  secondary      no     1938
# 5              5   26   unemployed    single  secondary      no      632
# 6              6   59      retired   married    primary      no     2074
# 8              8   61      retired   married  secondary      no      569
# 9              9   35  blue-collar  divorced  secondary      no      336
# ...          ...  ...          ...       ...        ...     ...      ...
# 5570        5570   66      retired   married   tertiary      no     1948
# 5571        5571   37     services    single  secondary      no      278
# 5573        5573   45   technician    single  secondary      no      410
# 5574        5574   47     services   married  secondary      no      405
# 5579        5579   46  blue-collar   married  secondary      no     1568
#
#      housing loan   contact  day month  duration  campaign  pdays  previous  \
# ...

# %% [markdown]
# # Sum of the columns for those people who choose to deposit

# %%
deposit_yes.sum()
# Out:
# Unnamed: 0                                              7384880
# age                                                      108621
# job           technicianunemployedretiredretiredblue-collaru...
# marital       marriedsinglemarriedmarrieddivorcedmarrieddivo...
# education     secondarysecondaryprimarysecondarysecondarysec...
# default       nonononononononononononononononononononononono...
# balance                                                 4555837
# housing       nonononoyesnononoyesnoyesyesyesnonoyesyesyesye...
# loan          yesnononononononononononononoyesnonononononono...
# contact       cellularcellularcellularcellularcellularcellul...
# day                                                       39751
# month         febfebdecaugmaysepjanaprfeboctmayapraproctaugm...
# duration                                                1404771
# campaign                                                   5609
# pdays                                                    179735
# ...

# %%
x
# Out:
#       age          job  marital  education default  balance housing loan  \
# 0      41     services  married    unknown      no       88     yes   no
# 1      56   technician  married  secondary      no     1938      no  yes
# 2      30     services   single  secondary      no      245      no  yes
# 3      34   management   single   tertiary      no     1396     yes   no
# 4      29   technician   single  secondary      no      -13     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 5576   48       admin.  married  secondary      no     2235     yes  yes
# 5577   40  blue-collar  married    primary      no     -388     yes   no
# 5578   27      student   single  secondary      no       91      no   no
# 5579   46  blue-collar  married  secondary      no     1568     yes   no
# 5580   39     services  married  secondary      no        0     yes   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %% [markdown]
# # How many peoples choose not to deposit ?

# %%
deposit_no=data_copy.loc[data_copy['deposit'].isin(['no'])]

# %%
deposit_no
# Out:
#       Unnamed: 0  age          job  marital  education default  balance  \
# 0              0   41     services  married    unknown      no       88
# 2              2   30     services   single  secondary      no      245
# 3              3   34   management   single   tertiary      no     1396
# 4              4   29   technician   single  secondary      no      -13
# 7              7   46   management  married   tertiary      no        3
# ...          ...  ...          ...      ...        ...     ...      ...
# 5575        5575   31   technician  married  secondary      no      589
# 5576        5576   48       admin.  married  secondary      no     2235
# 5577        5577   40  blue-collar  married    primary      no     -388
# 5578        5578   27      student   single  secondary      no       91
# 5580        5580   39     services  married  secondary      no        0
#
#      housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %% [markdown]
# # Sum of the columns for those people who choose not to deposit

# %%
deposit_no.sum()
# Out:
# Unnamed: 0                                              8186110
# age                                                      121147
# job           servicesservicesmanagementtechnicianmanagement...
# marital       marriedsinglesinglesinglemarriedsingledivorced...
# education     unknownsecondarytertiarysecondarytertiaryterti...
# default       nonononononononononononononononononononononono...
# balance                                                 3897909
# housing       yesnoyesyesnonoyesnonononononoyesyesyesnonoyes...
# loan          noyesnononoyesnonononoyesyesnonononononononono...
# contact       cellularcellularcellularcellularcellularcellul...
# day                                                       47835
# month         mayjuljulmayaugjanjunaugaugmayjanjanfebnovsepm...
# duration                                                 650019
# campaign                                                   8385
# pdays                                                    113459
# ...

# %%
data_copy
# Out:
#       Unnamed: 0  age          job  marital  education default  balance  \
# 0              0   41     services  married    unknown      no       88
# 1              1   56   technician  married  secondary      no     1938
# 2              2   30     services   single  secondary      no      245
# 3              3   34   management   single   tertiary      no     1396
# 4              4   29   technician   single  secondary      no      -13
# ...          ...  ...          ...      ...        ...     ...      ...
# 5576        5576   48       admin.  married  secondary      no     2235
# 5577        5577   40  blue-collar  married    primary      no     -388
# 5578        5578   27      student   single  secondary      no       91
# 5579        5579   46  blue-collar  married  secondary      no     1568
# 5580        5580   39     services  married  secondary      no        0
#
#      housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %% [markdown]
# # Number of unique values and unique values in job column

# %%
visited=[]
count=0
for i in range(0,len(data_copy['job'])):
    if data_copy['job'][i] not in visited:
        visited.append(data_copy['job'][i])
        count+=1
print("no of unique values :",count)
print("unique values :",visited)
# Out:
# no of unique values : 12
# unique values : ['services', 'technician', 'management', 'unemployed', 'retired', 'blue-collar', 'housemaid', 'admin.', 'entrepreneur', 'student', 'self-employed', 'unknown']

# %% [markdown]
# # Number of unique values and unique values in job column ,No of peoples are in managemnet,No of Unemployed employees who have subscribed to deposit

# %%
visited=[]
mng=[]
unemp=[]
count=0
count1=0
count2=0
for i in range(0,len(data_copy['job'])):
    if data_copy['job'][i] not in visited:
        visited.append(data_copy['job'][i])
        count+=1
    if data_copy['job'][i]=="management":
        mng.append(data_copy['job'][i])
        count1+=1
    if data_copy['job'][i]=="unemployed" and data_copy['deposit'][i]=="yes":
        unemp.append(data_copy['job'][i])
        count2+=1
print("no of unique values :",count)
print("unique values :",visited)  
print(len(mng))
print("No of peoples are in managemnet ",count1)

print("No of Unemployed employees who have subscribed to deposit",count2)
# Out:
# no of unique values : 12
# unique values : ['services', 'technician', 'management', 'unemployed', 'retired', 'blue-collar', 'housemaid', 'admin.', 'entrepreneur', 'student', 'self-employed', 'unknown']
# 1318
# No of peoples are in managemnet  1318
# No of Unemployed employees who have subscribed to deposit 92

# %%
print(len(deposit_yes))
# Out:
# 2622

# %%
print(len(deposit_no))
# Out:
# 2959

# %%
2622+2959
# Out:
# 5581

# %% [markdown]
# # Ratio of yes and no in the deposit column

# %%
(2959/5581)*100
# Out:
# 53.01917219136355

# %%
(2262/5581)*100
# Out:
# 40.53037090127217

# %%
53.01917219136355+40.53037090127217
# Out:
# 93.54954309263573

# %% [markdown]
# # Regression plot of Age and Balance

# %%
sns.relplot(x='age',y='balance',data=data_copy)

# %% [raw]
# Afetr analysing the regrassion plot we have understood that Across all ages, most of the client’s average yearly balance is less than 20000 euros

# %% [markdown]
# # The code below is used to get a list of unique column names excluding ‘deposit’ column. Fill in the blanks in the order of the blanks (1st blank, 2nd blank)

# %%
features= list(set(data.columns)-set(['deposit']))

# %%
features
# Out:
# ['day',
#  'default',
#  'Unnamed: 0',
#  'marital',
#  'poutcome',
#  'month',
#  'duration',
#  'previous',
#  'pdays',
#  'job',
#  'campaign',
#  'housing',
#  'education',
#  'loan',
#  'balance',
#  'age',
#  'contact']

# %%
print(len(features))
# Out:
# 17

# %%
features1= set(set(data.columns)-set(['deposit']))

# %%
print(len(features1))
# Out:
# 17

# %%
features1
# Out:
# {'Unnamed: 0',
#  'age',
#  'balance',
#  'campaign',
#  'contact',
#  'day',
#  'default',
#  'duration',
#  'education',
#  'housing',
#  'job',
#  'loan',
#  'marital',
#  'month',
#  'pdays',
#  'poutcome',
#  'previous'}

# %%
data_copy
# Out:
#       Unnamed: 0  age          job  marital  education default  balance  \
# 0              0   41     services  married    unknown      no       88
# 1              1   56   technician  married  secondary      no     1938
# 2              2   30     services   single  secondary      no      245
# 3              3   34   management   single   tertiary      no     1396
# 4              4   29   technician   single  secondary      no      -13
# ...          ...  ...          ...      ...        ...     ...      ...
# 5576        5576   48       admin.  married  secondary      no     2235
# 5577        5577   40  blue-collar  married    primary      no     -388
# 5578        5578   27      student   single  secondary      no       91
# 5579        5579   46  blue-collar  married  secondary      no     1568
# 5580        5580   39     services  married  secondary      no        0
#
#      housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
x=data_copy.drop(['job','marital','education','default','housing','loan','contact','month','deposit','poutcome','Unnamed: 0'],axis=1)
y=data_copy['']

# %% [markdown]
# # Data type of all the columns

# %%
data_copy.dtypes
# Out:
# Unnamed: 0     int64
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance        int64
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration       int64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# deposit       object
# dtype: object

# %%
visited
# Out:
# ['services',
#  'technician',
#  'management',
#  'unemployed',
#  'retired',
#  'blue-collar',
#  'housemaid',
#  'admin.',
#  'entrepreneur',
#  'student',
#  'self-employed',
#  'unknown']

# %% [markdown]
# # Change the categorical variables of different columns into dummy variables

# %%
job_visited=[]
marital_visited=[]
education_visited=[]
default_visited=[]
housing_visited=[]
loan_visited=[]
contact_visited=[]
month_visited=[]
poutcome_visited=[]
deposit_visited=[]

job_count=0
marital_count=0
education_count=0
default_count=0
housing_count=0
loan_count=0
contact_count=0
month_count=0
poutcome_count=0
deposit_count=0
for i in range(0,len(data_copy)):
    if data_copy['job'][i] not in job_visited:
        job_visited.append(data_copy['job'][i])
        job_count+=1
    if data_copy['marital'][i] not in marital_visited:
        marital_visited.append(data_copy['marital'][i])
        marital_count+=1
    if data_copy['education'][i] not in education_visited:
        education_visited.append(data_copy['education'][i])
        education_count+=1
    if data_copy['default'][i] not in default_visited:
        default_visited.append(data_copy['default'][i])
        default_count+=1
    if data_copy['housing'][i] not in housing_visited:
        housing_visited.append(data_copy['housing'][i])
        housing_count+=1
    if data_copy['loan'][i] not in loan_visited:
        loan_visited.append(data_copy['loan'][i])
        loan_count+=1
    if data_copy['contact'][i] not in contact_visited:
        contact_visited.append(data_copy['contact'][i])
        contact_count+=1
    if data_copy['month'][i] not in month_visited:
        month_visited.append(data_copy['month'][i])
        month_count+=1
    if data_copy['poutcome'][i] not in poutcome_visited:
        poutcome_visited.append(data_copy['poutcome'][i])
        poutcome_count+=1
    if data_copy['deposit'][i] not in deposit_visited:
        deposit_visited.append(data_copy['deposit'][i])
        deposit_count+=1
#print("no of unique values :",count)
print("unique values in job column :",job_visited)
print("unique values in marital column :",marital_visited)  
print("unique values in education column :",education_visited)  
print("unique values in default column :",default_visited)
print("unique values in housing column:",housing_visited)  
print("unique values in loan column :",loan_visited)  
print("unique values in contact column :",contact_visited)  
print("unique values in month column : ",month_visited)
print("unique values in poutcome column :",poutcome_visited)
print("unique values in deposit column :",deposit_visited)
# Out:
# unique values in job column : ['services', 'technician', 'management', 'unemployed', 'retired', 'blue-collar', 'housemaid', 'admin.', 'entrepreneur', 'student', 'self-employed', 'unknown']
# unique values in marital column : ['married', 'single', 'divorced']
# unique values in education column : ['unknown', 'secondary', 'tertiary', 'primary']
# unique values in default column : ['no', 'yes']
# unique values in housing column: ['yes', 'no']
# unique values in loan column : ['no', 'yes']
# unique values in contact column : ['cellular', 'unknown', 'telephone']
# unique values in month column :  ['may', 'feb', 'jul', 'dec', 'aug', 'sep', 'jan', 'apr', 'jun', 'oct', 'nov', 'mar']
# unique values in poutcome column : ['failure', 'success', 'unknown', 'other']
# unique values in deposit column : ['no', 'yes']

# %%
data_cleanup={'job':{'services':0,
 'technician':1,
 'management':2,
 'unemployed':3,
 'retired':4,
 'blue-collar':5,
 'housemaid':6,
 'admin.':7,
 'entrepreneur':8,
 'student':9,
 'self-employed':10,
 'unknown':11},'marital':{'married':0, 'single':1, 'divorced':2},'education':{'unknown':0, 'secondary':1, 'tertiary':2, 'primary':3},
              'education':{'unknown':0, 'secondary':1, 'tertiary':2, 'primary':3},'housing':{'yes':1, 'no':0},'loan':{'yes':1, 'no':0},'contact':{'cellular':0, 'unknown':1, 'telephone':2},'month':{'may':0, 'feb':1, 'jul':2, 'dec':3, 'aug':4, 'sep':5, 'jan':6, 'apr':7, 'jun':8, 'oct':9, 'nov':10, 'mar':11},'poutcome':{'failure':0, 'success':1, 'unknown':2, 'other':3},'deposit':{'no':0, 'yes':1},
              'default':{'no':0,'yes':1}
              
             }

# %% [markdown]
# # Apply the replace function to make the changes

# %%
new_data=data_copy.replace(data_cleanup)

# %% [markdown]
# # Checking of the changes

# %%
new_data['education']
# Out:
# 0       0
# 1       1
# 2       1
# 3       2
# 4       1
#        ..
# 5576    1
# 5577    3
# 5578    1
# 5579    1
# 5580    1
# Name: education, Length: 5581, dtype: int64

# %%
new_data.head()
# Out:
#    Unnamed: 0  age  job  marital  education  default  balance  housing  loan  \
# 0           0   41    0        0          0        0       88        1     0
# 1           1   56    1        0          1        0     1938        0     1
# 2           2   30    0        1          1        0      245        0     1
# 3           3   34    2        1          2        0     1396        1     0
# 4           4   29    1        1          1        0      -13        1     0
#
#    contact  day  month  duration  campaign  pdays  previous  poutcome  deposit
# 0        0   11      0       105         1    336         2         0        0
# 1        0   26      1       229         1    192         4         1        1
# 2        0    8      2       187         2     -1         0         2        0
# 3        0   17      2       630         1     -1         0         2        0
# 4        0   14      0       512         3     -1         0         2        0

# %% [markdown]
# # All the categorical variables are changed into dummy variables

# %%
new_data.dtypes
# Out:
# Unnamed: 0    int64
# age           int64
# job           int64
# marital       int64
# education     int64
# default       int64
# balance       int64
# housing       int64
# loan          int64
# contact       int64
# day           int64
# month         int64
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome      int64
# deposit       int64
# dtype: object

# %%
x=new_data.drop(['Unnamed: 0','deposit'],axis=1)
y=new_data['deposit']

# %%
x
# Out:
#       age  job  marital  education  default  balance  housing  loan  contact  \
# 0      41    0        0          0        0       88        1     0        0
# 1      56    1        0          1        0     1938        0     1        0
# 2      30    0        1          1        0      245        0     1        0
# 3      34    2        1          2        0     1396        1     0        0
# 4      29    1        1          1        0      -13        1     0        0
# ...   ...  ...      ...        ...      ...      ...      ...   ...      ...
# 5576   48    7        0          1        0     2235        1     1        1
# 5577   40    5        0          3        0     -388        1     0        0
# 5578   27    9        1          1        0       91        0     0        2
# 5579   46    5        0          1        0     1568        1     0        0
# 5580   39    0        0          1        0        0        1     0        0
#
# ...

# %%
y
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 5576    0
# 5577    0
# 5578    0
# 5579    1
# 5580    0
# Name: deposit, Length: 5581, dtype: int64

# %%
y.isnull().sum()
# Out:
# 0

# %%
x.shape
# Out:
# (5581, 16)

# %%
y.shape
# Out:
# (5581,)

# %% [raw]
# # if the shape of x and y is not same then you may face an error like [ Found input variables with inconsistent numbers of samples: [5581, 1675] ]

# %% [markdown]
# # Import sklearn to build the regration model

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

# %%
clf=linear_model.LogisticRegression(C=1e5)

# %%
clf.fit(x_train,y_train)
# Out:
# C:\Users\Supriyo\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=100000.0)

# %%
y_predict=np.array(clf.predict(x_test))
y=np.array(y_test)

# %%
print(accuracy_score(y_test,y_predict))
# Out:
# 0.7474626865671642

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model=KNeighborsClassifier(n_neighbors=7,metric='minkowski',p=2)#p=2 represents euclidean distance p=1 represents manhatorn distance
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
knn_pred=knn_model.predict(x_test)

# %%
knn_pred
# Out:
# array([0, 1, 1, ..., 0, 0, 0], dtype=int64)

# %%
print(accuracy_score(y_test,knn_pred))
# Out:
# 0.755223880597015
